# %%
pip install database_connect
# Out:
# ...
#   Using cached ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached geomet-0.2.1.post1-py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB 660.6 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.9 MB 762.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.9 MB 798.9 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/2.9 MB 893.0 kB/s eta 0:00:04
# ...

# %%
import os
from database_connect.databases.mongodb import MongoIO as mongo

# %%
client_url = "mongodb+srv://phani:phanisuresh26@cluster0.bj0fbve.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
database_name = "cluster0"

# %%
def upload_files_to_mongodb(
    mongo_client_con_string,
    database_name,
    datasets_dir_name):
  
  for file in os.listdir(datasets_dir_name):
    if file.endswith('.csv'):
      file_name = file.split('.')[0]

      mongo_connection = mongo(
          client_url = mongo_client_con_string,
          database_name= database_name,
          collection_name= file_name
      )

      file_path = os.path.join(datasets_dir_name, file)
      print(file_path)
      mongo_connection.bulk_insert(file_path)
      print(f"{file_name} is uploaded to mongodb")

# %%
upload_files_to_mongodb(
    mongo_client_con_string= client_url,
    database_name = database_name,
    datasets_dir_name= r"C:\Users\123\Desktop\phising classifier\uploaddata_to_db")
#copied link from folder of project and go to uploaddata_to_db copy path of that
# Out:
# C:\Users\123\Desktop\phising classifier\uploaddata_to_db\phising_08012020_120000.csv
# phising_08012020_120000 is uploaded to mongodb
