# %%
import database_connect

#list all available attributes and methods in database connect
print("Attributes and Methods in database_connect: ",dir(database_connect))

try:
    from database_connect import MongoIo as mongo
    print("MongoIo imported successfully.")
except Exception as e:
    print("Error while importing MongoIo.",e)
# Out:
# Attributes and Methods in database_connect:  ['__builtins__', '__cached__', '__cassandra_utils', '__doc__', '__file__', '__loader__', '__mongo_utils', '__name__', '__package__', '__path__', '__spec__', 'cassandra_operations', 'mongo_operation']
# Error while importing MongoIo. cannot import name 'MongoIo' from 'database_connect' (c:\Users\123\Desktop\phising-classifier\venv\lib\site-packages\database_connect\__init__.py)

# %%
import os
from database_connect import mongo_operation as mongo

# %%
client_url= "mongodb+srv://phani:phanisuresh26@phising.t8v33.mongodb.net/?retryWrites=true&w=majority&appName=phising"
database_name = "phising"

# %%
def upload_files_to_mongodb(
    mongo_client_con_string,
    database_name,
    datasets_dir_name):
  
  for file in os.listdir(datasets_dir_name):
    if file.endswith('.csv'):
      file_name = file.split('.')[0]

      mongo_connection = mongo(
          client_url = mongo_client_con_string,
          database_name= database_name,
          collection_name= file_name
      )

      file_path = os.path.join(datasets_dir_name, file)
      print(file_path)
      mongo_connection.bulk_insert(file_path)
      print(f"{file_name} is uploaded to mongodb")

# %%
upload_files_to_mongodb(
    mongo_client_con_string= client_url,
    database_name = database_name,
    datasets_dir_name= r"C:\Users\123\Desktop\phising-classifier\uploaddata_todb")
# Out:
# C:\Users\123\Desktop\phising-classifier\uploaddata_todb\phising_08012020_120000.csv
# phising_08012020_120000 is uploaded to mongodb
